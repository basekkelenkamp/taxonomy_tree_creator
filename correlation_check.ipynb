# %%
import pandas as pd
import seaborn as sns

df = pd.read_csv("input-data/adult-dataset.csv")

# %%
df.corr('pearson').style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_dbca8_row0_col0, #T_dbca8_row1_col1, #T_dbca8_row2_col2, #T_dbca8_row3_col3, #T_dbca8_row4_col4, #T_dbca8_row5_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_dbca8_row0_col1, #T_dbca8_row1_col0, #T_dbca8_row1_col2, #T_dbca8_row1_col5, #T_dbca8_row3_col4, #T_dbca8_row4_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_dbca8_row0_col2 {
#   background-color: #e8f1fa;
#   color: #000000;
# }
# #T_dbca8_row0_col3, #T_dbca8_row2_col4, #T_dbca8_row5_col3 {
#   background-color: #e2edf8;
#   color: #000000;
# }
# #T_dbca8_row0_col4 {
#   background-color: #e6f0f9;
#   color: #000000;
# }
# #T_dbca8_row0_col5, #T_dbca8_row5_col4 {
#   background-color: #e7f0fa;
#   color: #000000;
# }
# #T_dbca8_row1_col3, #T_dbca8_row2_col1 {
#   background-color: #f2f7fd;
#   color: #000000;
# }
# #T_dbca8_row1_col4 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_dbca8_row2_col0 {
#   background-color: #e3eef8;
# ...

# %%
df.corr('spearman').style.background_gradient(cmap="Blues")
# Out:
# <style type="text/css">
# #T_fca23_row0_col0, #T_fca23_row1_col1, #T_fca23_row2_col2, #T_fca23_row3_col3, #T_fca23_row4_col4, #T_fca23_row5_col5 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_fca23_row0_col1, #T_fca23_row1_col0, #T_fca23_row1_col2, #T_fca23_row1_col5, #T_fca23_row3_col4, #T_fca23_row4_col3 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_fca23_row0_col2 {
#   background-color: #e3eef9;
#   color: #000000;
# }
# #T_fca23_row0_col3 {
#   background-color: #d4e4f4;
#   color: #000000;
# }
# #T_fca23_row0_col4, #T_fca23_row5_col4 {
#   background-color: #dfecf7;
#   color: #000000;
# }
# #T_fca23_row0_col5 {
#   background-color: #d7e6f5;
#   color: #000000;
# }
# #T_fca23_row1_col3, #T_fca23_row1_col4 {
#   background-color: #ecf4fb;
#   color: #000000;
# }
# #T_fca23_row2_col0 {
#   background-color: #dceaf6;
#   color: #000000;
# }
# #T_fca23_row2_col1 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_fca23_row2_col3 {
# ...

# %%
import seaborn as sns
# %matplotlib inline

# Plot distribution (smoothed 3)
# sns.displot(df, x="hours-per-week", kind="kde", bw_adjust=3)

# Plot distribution (smoothed 5)
# sns.displot(df, x="hours-per-week", kind="kde", bw_adjust=5)

# Plot all distributions (smoothed 3)
# df_numerical = df.select_dtypes(include='number')
# for i in df_numerical:
#   sns.displot(df_numerical, x=f"{i}", kind="kde", bw_adjust=3)

# Plot distribution of how many days people work vs years of education
# sns.displot(x='hours-per-week',y='education-num',data=df,binwidth=(8, 1))

# Plot distribution of 
# sns.pairplot(df, hue='education-num', palette='coolwarm')

# %%
import seaborn as sns
# %matplotlib inline

# Plot all distributions (smoothed 3)
df_numerical = df.select_dtypes(include='number')
for i in df_numerical:
  sns.displot(df_numerical, x=f"{i}", kind="kde", bw_adjust=3)
