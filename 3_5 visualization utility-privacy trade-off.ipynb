# %%
import matplotlib.pyplot as plt

# Scenario a
k_values =      [2, 5, 10, 15, 20, 25, 30, 40, 50, 75]
U_values_a =   [81.89859, 
                81.97844, 
                81.91702, 
                81.69589, 
                82.02451, 
                81.82181, 
                81.96923, 
                81.36728, 
                82.03986, 
                81.87709]
P_values_a =   [0.38725, 
                0.39511, 
                0.35058, 
                0.33422, 
                0.35679, 
                0.34434, 
                0.27091, 
                0.45238, 
                0.35811, 
                0.26577]

fig, ax = plt.subplots()

title = "Utility-privacy trade-off - Scenario A detailed"

for i, k in enumerate(k_values):
    ax.scatter(U_values_a[i], P_values_a[i], label = f'k = {k}')

plt.xlabel('Utility: Accuracy of income (%)')
plt.ylabel('Privacy: Average risk (%)')
plt.title(title)
# plt.legend()
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig(f"output-data/{title}.png", dpi = 150, bbox_inches='tight')
plt.show()

# %%
import matplotlib.pyplot as plt

# Scenario a
k_values =      [2, 5, 10, 15, 20, 25, 30, 40, 50, 75]
U_values_a =   [83.66758, 
                83.65836, 
                84.23881, 
                82.32548, 
                81.89245, 
                82.30398, 
                82.22720, 
                82.26099, 
                82.20571, 
                81.24000]
P_values_a =   [4.19229, 
                2.05917, 
                0.78850, 
                0.66781, 
                0.56105, 
                0.51087, 
                0.34763, 
                0.26210, 
                0.25791, 
                0.23046]

fig, ax = plt.subplots()

title = "Utility-privacy trade-off - Scenario B detailed"

for i, k in enumerate(k_values):
    ax.scatter(U_values_a[i], P_values_a[i], label = f'k = {k}')

plt.xlabel('Utility: Accuracy of income (%)')
plt.ylabel('Privacy: Average risk (%)')
plt.title(title)
# plt.legend()
ax.legend(loc='center left', bbox_to_anchor=(1, 0.5))
plt.savefig(f"output-data/{title}.png", dpi = 150, bbox_inches='tight')
plt.show()
